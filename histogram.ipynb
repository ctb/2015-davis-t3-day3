# %%
ls
# Out:
# Makefile                 calc-error-spectrum.py~  make-reads.py~
# Makefile~                fake-genome.py           reads.fa
# Untitled0.ipynb          genome.fa
# calc-error-spectrum.py   make-reads.py

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['hist']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
ls
# Out:
# Makefile                 calc-error-spectrum.py~  make-reads.py
# Makefile~                error-hist.csv           make-reads.py~
# Untitled0.ipynb          fake-genome.py           reads.fa
# calc-error-spectrum.py   genome.fa

# %%
ls
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-345a3cc06ce6> in <module>()
# ----> 1 ls
#       2 d
#
# NameError: name 'ls' is not defined

# %%
hist = numpy.loadtxt('error-hist.csv', delimiter=',')

# %%
plot(hist[:,0], hist[:,1])
xlabel('position in read')
ylabel('count of errors at that position')
axis(ymin=0)
# Out:
# (0.0, 100.0, 0, 14.0)

# %%
rnahist = numpy.loadtxt('rna-hist.csv', delimiter=',')
plot(rnahist[:,0], rnahist[:,1])
xlabel('position in read')
ylabel('count of errors at that position')
axis(ymin=0, ymax=10000)
# Out:
# (0.0, 80.0, 0, 10000)
